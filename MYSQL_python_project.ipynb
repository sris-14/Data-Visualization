# %%
import mysql.connector as my

con = my.connect(
    host='localhost',
    user = 'root',
    password ='srishti',
    database='ecommerce'
)

cr = con.cursor()

cr.execute("""CREATE TABLE customer (
    customer_id VARCHAR(10) NOT NULL,   
    name VARCHAR(100) NOT NULL,         
    city VARCHAR(65) NOT NULL,          
    email VARCHAR(45) NOT NULL,         
    phone_no VARCHAR(15) NOT NULL,   
    address VARCHAR(100) NOT NULL,      
    pin_code INT NOT NULL,             
    PRIMARY KEY (customer_id)  )         
""")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cr.execute("""INSERT INTO customer (customer_id, name, city, email, phone_no, address, pin_code) VALUES
('CUST001', 'John Doe', 'New York', 'johndoe@example.com', '1234567890', '123 Elm Street', 10001),
('CUST002', 'Jane Smith', 'Los Angeles', 'janesmith@example.com', '0987654321', '456 Oak Avenue', 90001),
('CUST003', 'Alice Johnson', 'Chicago', 'alicej@example.com', '1122334455', '789 Pine Lane', 60601),
('CUST004', 'Bob Brown', 'Houston', 'bobbrown@example.com', '2233445566', '321 Cedar Road', 77001),
('CUST005', 'Charlie Davis', 'Phoenix', 'charlied@example.com', '3344556677', '654 Maple Court', 85001),
('CUST006', 'Diana Miller', 'Philadelphia', 'dianam@example.com', '4455667788', '987 Birch Street', 19101),
('CUST007', 'Eve Wilson', 'San Antonio', 'evew@example.com', '5566778899', '159 Elmwood Drive', 78201),
('CUST008', 'Frank Taylor', 'San Diego', 'frankt@example.com', '6677889900', '753 Willow Way', 92101),
('CUST009', 'Grace Lee', 'Dallas', 'gracel@example.com', '7788990011', '852 Chestnut Blvd', 75201),
('CUST010', 'Henry White', 'San Jose', 'henryw@example.com', '8899001122', '951 Poplar Place', 95101),
('CUST011', 'Ivy Green', 'Austin', 'ivyg@example.com', '9900112233', '357 Spruce Terrace', 73301),
('CUST012', 'Jack Black', 'Jacksonville', 'jackb@example.com', '1010101010', '159 Pinewood Crescent', 32099), 
('CUST013', 'Karen Hall', 'Fort Worth', 'karenh@example.com', '1112131415', '963 Redwood Drive', 76101),
('CUST014', 'Liam Young', 'Columbus', 'liamy@example.com', '1213141516', '753 Cedar Grove', 43085),
('CUST015', 'Mia Harris', 'Charlotte', 'miah@example.com', '1314151617', '456 Elm Grove', 28201),
('CUST016', 'Noah King', 'San Francisco', 'noahk@example.com', '1415161718', '258 Palm Street', 94101),
('CUST017', 'Olivia Scott', 'Indianapolis', 'olivias@example.com', '1516171819', '369 Birch Court', 46201),
('CUST018', 'Paul Moore', 'Seattle', 'paulm@example.com', '1617181920', '741 Maple Avenue', 98101),
('CUST019', 'Quinn Lewis', 'Denver', 'quinnl@example.com', '1718192021', '852 Oak Street', 80201),
('CUST020', 'Rachel Walker', 'Washington', 'rachelw@example.com', '1820212223', '951 Walnut Lane', 20001);""")

con.commit()
print("succesfully")

cr.execute('''update customer set city = 'Indianapolis' where customer_id in ('CUST008','CUST009','CUST010')''')
cr.execute('''update customer set city = 'Los Angeles' where customer_id in ('CUST011','CUST012')''')
cr.execute('''update customer set city = 'Washington' where customer_id in ('CUST013','CUST014')''')
cr.execute('''update customer set city = 'Houston' where customer_id in ('CUST017','CUST018','CUST019')''')
cr.execute('''update customer set city = 'New York' where customer_id in ('CUST020')''')
cr.execute('''update customer set city = 'Columbus' where customer_id in ('CUST015','CUST016')''')

con.commit()
print("Data Updated Successfully..")

# %%
cr.execute("""CREATE TABLE `product` (
  `product_id` VARCHAR(10) NOT NULL,
  `product_name` VARCHAR(100) NOT NULL,
  `category` VARCHAR(65) NOT NULL,
  `sub_category` VARCHAR(45) NOT NULL,
  `original_price` DOUBLE NOT NULL,
  `selling_price` DOUBLE NOT NULL,
  `stock` INT NOT NULL,
  PRIMARY KEY (`product_id`)
);
""")

# %%
cr.execute("""INSERT INTO product (product_id, product_name, category, sub_category, original_price, selling_price, stock) VALUES
('P001', 'Wireless Mouse', 'Electronics', 'Computer Accessories', 20.00, 15.99, 150),
('P002', 'Bluetooth Keyboard', 'Electronics', 'Computer Accessories', 30.00, 24.99, 100),
('P003', 'Smartphone', 'Electronics', 'Mobile Phones', 500.00, 449.99, 50),
('P004', 'Laptop', 'Electronics', 'Computers', 1000.00, 899.99, 30),
('P005', 'Tablet', 'Electronics', 'Tablets', 300.00, 279.99, 60),
('P006', 'Gaming Headset', 'Electronics', 'Audio', 80.00, 69.99, 200),
('P007', '4K Monitor', 'Electronics', 'Displays', 400.00, 349.99, 40),
('P008', 'Portable Speaker', 'Electronics', 'Audio', 50.00, 39.99, 120),
('P009', 'Digital Camera', 'Electronics', 'Cameras', 600.00, 549.99, 25),
('P010', 'Smart Watch', 'Electronics', 'Wearables', 150.00, 129.99, 80),
('P011', 'Running Shoes', 'Footwear', 'Sports', 120.00, 99.99, 70),
('P012', 'Leather Jacket', 'Apparel', 'Outerwear', 200.00, 169.99, 45),
('P013', 'T-shirt', 'Apparel', 'Casual', 25.00, 19.99, 200),
('P014', 'Jeans', 'Apparel', 'Casual', 60.00, 49.99, 150),
('P015', 'Formal Shirt', 'Apparel', 'Formal Wear', 40.00, 34.99, 90),
('P016', 'Blender', 'Home Appliances', 'Kitchen Appliances', 70.00, 59.99, 100),
('P017', 'Microwave Oven', 'Home Appliances', 'Kitchen Appliances', 200.00, 179.99, 40),
('P018', 'Vacuum Cleaner', 'Home Appliances', 'Cleaning Appliances', 150.00, 129.99, 30),
('P019', 'Refrigerator', 'Home Appliances', 'Large Appliances', 1200.00, 1099.99, 20),
('P020', 'Washing Machine', 'Home Appliances', 'Large Appliances', 800.00, 699.99, 15);
""")
con.commit()
print("succesfully")

# %%
cr.execute("""CREATE TABLE `order_details` (
  `order_id` INT NOT NULL AUTO_INCREMENT,
  `customer_id` VARCHAR(10) NOT NULL,
  `product_id` VARCHAR(10) NOT NULL,
  `quantity` DOUBLE NOT NULL,
  `total_price` DOUBLE NOT NULL,
  `payment_mode` VARCHAR(60) NOT NULL,
  `order_date` DATETIME DEFAULT NULL,
  `order_status` VARCHAR(20) NOT NULL,
  PRIMARY KEY (`order_id`),
  KEY `customer_id` (`customer_id`),
  KEY `product_id` (`product_id`),
  CONSTRAINT `order_details_ibfk_1` FOREIGN KEY (`customer_id`)
  REFERENCES `customer` (`customer_id`),
  CONSTRAINT `order_details_ibfk_2` FOREIGN KEY (`product_id`)
  REFERENCES `product` (`product_id`)
)
""")

cr.execute("""INSERT INTO order_details (customer_id, product_id, quantity, total_price, payment_mode, order_date, order_status) VALUES
('CUST001', 'P001', 2, 31.98, 'Credit Card', '2024-08-01 10:00:00', 'Shipped'),
('CUST002', 'P003', 1, 449.99, 'PayPal', '2024-08-02 11:30:00', 'Delivered'),
('CUST003', 'P002', 3, 74.97, 'Credit Card', '2024-08-03 12:15:00', 'Pending'),
('CUST004', 'P005', 1, 279.99, 'Debit Card', '2024-08-04 13:45:00', 'Processing'),
('CUST005', 'P004', 1, 899.99, 'Credit Card', '2024-08-05 14:20:00', 'Shipped'),
('CUST006', 'P007', 2, 699.98, 'PayPal', '2024-08-06 15:10:00', 'Delivered'),
('CUST007', 'P006', 4, 279.96, 'Credit Card', '2024-08-07 16:30:00', 'Pending'),
('CUST008', 'P009', 1, 549.99, 'Debit Card', '2024-08-08 17:00:00', 'Processing'),
('CUST009', 'P010', 2, 259.98, 'Credit Card', '2024-08-09 18:30:00', 'Shipped'),
('CUST010', 'P012', 1, 169.99, 'PayPal', '2024-08-10 19:45:00', 'Delivered'),
('CUST011', 'P011', 3, 299.97, 'Credit Card', '2024-08-11 20:10:00', 'Pending'),
('CUST012', 'P013', 5, 99.95, 'Debit Card', '2024-08-12 21:20:00', 'Processing'),
('CUST013', 'P014', 2, 99.98, 'Credit Card', '2024-08-13 09:00:00', 'Shipped'),
('CUST014', 'P016', 1, 59.99, 'PayPal', '2024-08-14 08:30:00', 'Delivered'),
('CUST015', 'P017', 1, 179.99, 'Credit Card', '2024-08-15 07:45:00', 'Pending'),
('CUST016', 'P018', 2, 259.98, 'Debit Card', '2024-08-16 06:30:00', 'Processing'),
('CUST017', 'P019', 1, 1099.99, 'Credit Card', '2024-08-17 05:20:00', 'Shipped'),
('CUST018', 'P020', 1, 699.99, 'PayPal', '2024-08-18 04:10:00', 'Delivered'),
('CUST019', 'P015', 4, 139.96, 'Credit Card', '2024-08-19 03:00:00', 'Pending'),
('CUST020', 'P008', 3, 119.97, 'Debit Card', '2024-08-20 02:50:00', 'Processing');
""")

con.commit()
print("succesfully")
# Out:
# succesfully

# %%
import mysql.connector
import pandas as pd
import seaborn as sns

cr = con.cursor()
# Query data from the 'customer' table
cr.execute('SELECT * FROM customer')
#After fetching data from the database we are storing it into Pandas DataFrame
customer_data = pd.DataFrame(cr.fetchall(), columns=[desc[0] for desc in
cr.description])
# Query data from the 'product' table
cr.execute('SELECT * FROM product')
product_data = pd.DataFrame(cr.fetchall(), columns=[desc[0] for desc in
cr.description])
# Query data from the 'order_details' table
cr.execute('SELECT * FROM order_details')
order_data = pd.DataFrame(cr.fetchall(), columns=[desc[0] for desc in
cr.description])
#printing first 5 records from customer table
customer_data.head()
# Out:
#   customer_id           name         city                  email    phone_no  \
# 0     CUST001       John Doe     New York    johndoe@example.com  1234567890
# 1     CUST002     Jane Smith  Los Angeles  janesmith@example.com  0987654321
# 2     CUST003  Alice Johnson      Chicago     alicej@example.com  1122334455
# 3     CUST004      Bob Brown      Houston   bobbrown@example.com  2233445566
# 4     CUST005  Charlie Davis      Phoenix   charlied@example.com  3344556677
#
#            address  pin_code
# 0   123 Elm Street     10001
# 1   456 Oak Avenue     90001
# 2    789 Pine Lane     60601
# 3   321 Cedar Road     77001
# 4  654 Maple Court     85001

# %%
#printing first 5 records from product table
product_data.head()
# Out:
#   product_id        product_name     category          sub_category  \
# 0       P001      Wireless Mouse  Electronics  Computer Accessories
# 1       P002  Bluetooth Keyboard  Electronics  Computer Accessories
# 2       P003          Smartphone  Electronics         Mobile Phones
# 3       P004              Laptop  Electronics             Computers
# 4       P005              Tablet  Electronics               Tablets
#
#    original_price  selling_price  stock
# 0            20.0          15.99    150
# 1            30.0          24.99    100
# 2           500.0         449.99     50
# 3          1000.0         899.99     30
# 4           300.0         279.99     60

# %%
#printing first 5 records from order_details table
order_data.head()
# Out:
#    order_id customer_id product_id  quantity  total_price payment_mode  \
# 0        41     CUST001       P001       2.0        31.98  Credit Card
# 1        42     CUST002       P003       1.0       449.99       PayPal
# 2        43     CUST003       P002       3.0        74.97  Credit Card
# 3        44     CUST004       P005       1.0       279.99   Debit Card
# 4        45     CUST005       P004       1.0       899.99  Credit Card
#
#            order_date order_status
# 0 2024-08-01 10:00:00      Shipped
# 1 2024-08-02 11:30:00    Delivered
# 2 2024-08-03 12:15:00      Pending
# 3 2024-08-04 13:45:00   Processing
# 4 2024-08-05 14:20:00      Shipped

# %%
# display basic information about the customer data
print(customer_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  20 non-null     object
#  1   name         20 non-null     object
#  2   city         20 non-null     object
#  3   email        20 non-null     object
#  4   phone_no     20 non-null     object
#  5   address      20 non-null     object
#  6   pin_code     20 non-null     int64
# dtypes: int64(1), object(6)
# memory usage: 1.2+ KB
# None

# %%
# display basic information about the product data
print(product_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      20 non-null     object
#  1   product_name    20 non-null     object
#  2   category        20 non-null     object
#  3   sub_category    20 non-null     object
#  4   original_price  20 non-null     float64
#  5   selling_price   20 non-null     float64
#  6   stock           20 non-null     int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 1.2+ KB
# None

# %%
# display basic information about the order data
print(order_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      240 non-null    int64
#  1   customer_id   240 non-null    object
#  2   product_id    240 non-null    object
#  3   quantity      240 non-null    float64
#  4   total_price   240 non-null    float64
#  5   payment_mode  240 non-null    object
#  6   order_date    240 non-null    datetime64[ns]
#  7   order_status  240 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 15.1+ KB
# None

# %%
# display basic statistics about customer data
print(customer_data.describe())
# Out:
#            pin_code
# count     20.000000
# mean   63685.100000
# std    28896.667814
# min    10001.000000
# 25%    40338.500000
# 50%    75651.000000
# 75%    86251.000000
# max    98101.000000

# %%
# display basic statistics about product data
print(product_data.describe())
# Out:
#        original_price  selling_price       stock
# count       20.000000      20.000000   20.000000
# mean       299.750000     267.790000   80.750000
# std        348.177492     316.374961   57.474823
# min         20.000000      15.990000   15.000000
# 25%         57.500000      47.490000   37.500000
# 50%        150.000000     129.990000   65.000000
# 75%        425.000000     374.990000  105.000000
# max       1200.000000    1099.990000  200.000000

# %%
# display basic statistics about customer data
print(order_data.describe())
# Out:
#         order_id    quantity  total_price           order_date
# count  240.00000  240.000000   240.000000                  240
# mean   160.50000    2.050000   337.829500  2024-08-10 23:52:00
# min     41.00000    1.000000    31.980000  2024-08-01 10:00:00
# 25%    100.75000    1.000000   114.972500  2024-08-06 08:57:30
# 50%    160.50000    2.000000   259.980000  2024-08-11 07:57:30
# 75%    220.25000    3.000000   474.990000  2024-08-15 13:26:15
# max    280.00000    5.000000  1099.990000  2024-08-20 02:50:00
# std     69.42622    1.205635   294.702892                  NaN

# %%
# check null values in data
print(customer_data.isna().sum())
print("\n")
print(product_data.isna().sum())
print("\n")
print(order_data.isna().sum())
# Out:
# customer_id    0
# name           0
# city           0
# email          0
# phone_no       0
# address        0
# pin_code       0
# dtype: int64
#
#
# product_id        0
# product_name      0
# category          0
# sub_category      0
# original_price    0
# selling_price     0
# stock             0
# dtype: int64
#
#
# order_id        0
# customer_id     0
# product_id      0
# quantity        0
# total_price     0
# payment_mode    0
# order_date      0
# order_status    0
# dtype: int64

# %%
# print(customer_data.dropna())
# print(product_data.dropna())
# print(order_data.dropna())

# %%
# check for duplicate values
print("In Customer data:",customer_data.duplicated().any())
print("\n")
print("In product data:",product_data.duplicated().any())
print("\n")
print("In Order data:",order_data.duplicated().any())
# Out:
# In Customer data: False
#
#
# In product data: False
#
#
# In Order data: False

# %%
# print(customer_data.drop_duplicates())
# print(product_data.drop_duplicates())
# print(order_data.drop_duplicates())

# %%
# Aggregate the number of customers by city
city_counts = customer_data['city'].value_counts()
city_counts
# Out:
# city
# Houston         4
# Los Angeles     3
# Indianapolis    3
# New York        2
# Washington      2
# Columbus        2
# Philadelphia    1
# Phoenix         1
# Chicago         1
# San Antonio     1
# Name: count, dtype: int64

# %%
# Create and display a bar graph
plt.figure(figsize=(10, 6))
city_counts.plot(kind='bar', color='skyblue')
plt.title('Total Number of Customers by City')
plt.xlabel('City')
plt.ylabel('Number of Customers')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Count orders per customer
order_counts = order_data['customer_id'].value_counts()

# Convert to DataFrame for better readability
order_counts_df = order_counts.reset_index()
order_counts_df.columns = ['customer_id', 'number_of_orders']

# Merge with customer data to get names
customer_orders_df = pd.merge(order_counts_df, customer_data, on='customer_id')

# Sort by number of orders in descending order
customer_orders_df = customer_orders_df.sort_values(by='number_of_orders', ascending=False)

# Plotting the bar chart
plt.figure(figsize=(12, 8))
plt.bar(customer_orders_df['name'], customer_orders_df['number_of_orders'], color='skyblue')
plt.title('Most Frequent Customers by Number of Orders')
plt.xlabel('Customer Name')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Display the chart
plt.show()

# %%
# Count products per category
category_counts = product_data['category'].value_counts()

# Convert to DataFrame for better readability
category_counts_df = category_counts.reset_index()
category_counts_df.columns = ['Category', 'Number of Products']

# Plotting the bar chart
plt.figure(figsize=(7, 4))
plt.bar(category_counts_df['Category'], category_counts_df['Number of Products'], color='lightpink')
plt.title('Total Number of Products by Category')
plt.xlabel('Category')
plt.ylabel('Number of Products')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Display the chart
plt.show()

# %%
# Count the number of products per sub-category
sub_category_counts = product_data['sub_category'].value_counts()

# Convert to DataFrame for better readability
sub_category_counts_df = sub_category_counts.reset_index()
sub_category_counts_df.columns = ['Sub-Category', 'Number of Products']

# Plotting the bar chart
plt.figure(figsize=(12, 8))
plt.bar(sub_category_counts_df['Sub-Category'], sub_category_counts_df['Number of Products'], color='skyblue')
plt.title('Distribution of Products Across Sub-Categories')
plt.xlabel('Sub-Category')
plt.ylabel('Number of Products')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Display the chart
plt.show()

# %%
# Calculate statistics
average_price = product_data['selling_price'].mean()
max_price = product_data['selling_price'].max()
min_price = product_data['selling_price'].min()

# Prepare data for the bar graph
statistics = {
    'Average Price': average_price,
    'Maximum Price': max_price,
    'Minimum Price': min_price
}

# Create and display a bar graph
plt.figure(figsize=(7, 4))
plt.bar(statistics.keys(), statistics.values(), color=['skyblue', 'salmon', 'lightgreen'])
plt.title('Product Selling Price Statistics')
plt.xlabel('Price Type')
plt.ylabel('Price')
plt.tight_layout()
plt.show()

# %%
cr = con.cursor()
# Query data from the 'product' table to get product names
cr.execute('SELECT product_id, product_name FROM product')
product_names = pd.DataFrame(cr.fetchall(), columns=['product_id', 'product_name'])

# Merge the order data with product names
order_data = order_data.merge(product_names, on='product_id')

# Calculate total quantity ordered by each product
product_quantity = order_data.groupby('product_name').agg({'quantity': 'sum'}).reset_index()

# Sort the products by total quantity in descending order and get the top 10
top_10_products = product_quantity.sort_values(by='quantity', ascending=False).head(10)
# Plotting the bar chart
plt.figure(figsize=(12, 8))
plt.bar(top_10_products['product_name'], top_10_products['quantity'], color='cornflowerblue')
plt.title('Top 10 Products by Total Order Quantity')
plt.xlabel('Product Name')
plt.ylabel('Total Quantity Ordered')
plt.xticks(rotation=45, ha='right') 
plt.tight_layout()

# Display the chart
plt.show()

# Display the top 10 products
print(top_10_products)
# Out:
#           product_name  quantity
# 15             T-shirt      60.0
# 4         Formal Shirt      48.0
# 5       Gaming Headset      48.0
# 2   Bluetooth Keyboard      36.0
# 12       Running Shoes      36.0
# 10    Portable Speaker      36.0
# 0           4K Monitor      24.0
# 13         Smart Watch      24.0
# 19      Wireless Mouse      24.0
# 6                Jeans      24.0

# %%
status_counts = order_data['order_status'].value_counts()
print(status_counts)

# Plotting
status_counts.plot(kind='pie', figsize=(10, 7), autopct='%1.1f%%', colors=['#ff9898','#66beff','#99ff89','#ffcc99'])#['lightpink','skyblue','palegreen','peach']
plt.title('Order Status Distribution')
plt.ylabel('')
plt.show()
# Out:
# order_status
# Shipped       60
# Delivered     60
# Pending       60
# Processing    60
# Name: count, dtype: int64

# %%
# Query data from the 'order_details' table
cr.execute('''
    SELECT product_id, SUM(quantity) AS total_quantity
    FROM order_details
    GROUP BY product_id
''')

# Store the data into a Pandas DataFrame
order_data = pd.DataFrame(cr.fetchall(), columns=['product_id', 'total_quantity'])

cr.execute('SELECT product_id, product_name FROM product')

# Store product names into a Pandas DataFrame
product_names = pd.DataFrame(cr.fetchall(), columns=['product_id', 'product_name'])

# Merge product names with order data
order_data = order_data.merge(product_names, on='product_id')

# Sort and select the most popular products based on quantity
most_popular_products = order_data.sort_values(by='total_quantity', ascending=False)

# Optionally, you can limit to top N products
top_n = 10
most_popular_products = most_popular_products.head(top_n)

# Create and display a bar graph
plt.figure(figsize=(14, 7))
plt.barh(most_popular_products['product_name'], most_popular_products['total_quantity'], color='skyblue')
plt.title(f'Top {top_n} Most Popular Products by Quantity')
plt.xlabel('Product Name')
plt.ylabel('Total Quantity Ordered')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Print the most popular products
print(most_popular_products)
# Out:
#    product_id  total_quantity        product_name
# 12       P013            60.0             T-shirt
# 5        P006            48.0      Gaming Headset
# 14       P015            48.0        Formal Shirt
# 1        P002            36.0  Bluetooth Keyboard
# 10       P011            36.0       Running Shoes
# 7        P008            36.0    Portable Speaker
# 0        P001            24.0      Wireless Mouse
# 13       P014            24.0               Jeans
# 17       P018            24.0      Vacuum Cleaner
# 6        P007            24.0          4K Monitor

# %%
# Create a cursor object
cr = con.cursor()

# Query data to get total revenue by product
cr.execute('''
    SELECT product_id, SUM(total_price) AS total_revenue
    FROM order_details
    GROUP BY product_id
    ORDER BY total_revenue DESC
''')
revenue_data = pd.DataFrame(cr.fetchall(), columns=['product_id', 'total_revenue'])


cr.execute('SELECT product_id, product_name FROM product')
product_names = pd.DataFrame(cr.fetchall(), columns=['product_id', 'product_name'])



# Merge revenue data with product names
revenue_data = revenue_data.merge(product_names, on='product_id')

# Plotting the bar chart
plt.figure(figsize=(12, 8))
plt.bar(revenue_data['product_name'], revenue_data['total_revenue'], color='skyblue')
plt.title('Total Revenue Generated from Orders (Product-wise)')
plt.xlabel('Product Name')
plt.ylabel('Total Revenue ($)')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()

# Display the chart
plt.show()

# Display the revenue data
print(revenue_data[['product_name', 'total_revenue']])
# Out:
#           product_name  total_revenue
# 0         Refrigerator       13199.88
# 1               Laptop       10799.88
# 2      Washing Machine        8399.88
# 3           4K Monitor        8399.76
# 4       Digital Camera        6599.88
# 5           Smartphone        5399.88
# 6        Running Shoes        3599.64
# 7               Tablet        3359.88
# 8       Gaming Headset        3359.52
# 9          Smart Watch        3119.76
# 10      Vacuum Cleaner        3119.76
# 11      Microwave Oven        2159.88
# 12      Leather Jacket        2039.88
# 13        Formal Shirt        1679.52
# 14    Portable Speaker        1439.64
# 15               Jeans        1199.76
# 16             T-shirt        1199.40
# 17  Bluetooth Keyboard         899.64
# 18             Blender         719.88
# 19      Wireless Mouse         383.76

# %%
# Query data from the 'order_details' table
cr.execute('''
    SELECT product_id, SUM(total_price) AS total_revenue
    FROM order_details
    GROUP BY product_id
''')

# Store the data into a Pandas DataFrame
order_revenue = pd.DataFrame(cr.fetchall(), columns=['product_id', 'total_revenue'])

# Query product categories
cr.execute('SELECT product_id, category FROM product')

# Store product categories into a Pandas DataFrame
product_categories = pd.DataFrame(cr.fetchall(), columns=['product_id', 'category'])

# Merge product categories with revenue data
revenue_with_category = order_revenue.merge(product_categories, on='product_id')

# Aggregate revenue by category
category_revenue = revenue_with_category.groupby('category')['total_revenue'].sum().reset_index()

# Calculate total revenue
total_revenue = category_revenue['total_revenue'].sum()

# Calculate percentage of total revenue for each category
category_revenue['percentage'] = (category_revenue['total_revenue'] / total_revenue) * 100

# Step 4: (Optional) Create and display a pie chart
plt.figure(figsize=(10, 8))
plt.pie(category_revenue['percentage'], labels=category_revenue['category'], autopct='%1.1f%%', colors=plt.cm.Paired(range(len(category_revenue))))
plt.title('Revenue Distribution by Product Category')
plt.show()

# Print the revenue and percentage by category
print(category_revenue)
# Out:
#           category  total_revenue  percentage
# 0          Apparel        6118.56    7.546410
# 1      Electronics       43761.60   53.973972
# 2         Footwear        3599.64    4.439666
# 3  Home Appliances       27599.28   34.039952

# %%
# Query to get total revenue from all orders
cr.execute('''
    SELECT SUM(total_price) AS total_revenue
    FROM order_details
''')
# Fetch the result
result = cr.fetchone()

# Extract total revenue from the result
total_revenue = result[0]

# Create a DataFrame for plotting
data = {'Total Revenue': [total_revenue]}
df = pd.DataFrame(data)

# Create and display a bar graph
plt.figure(figsize=(8, 6))
plt.bar(df.index, df['Total Revenue'], color='skyblue')
plt.title('Total Revenue Generated from All Orders')
plt.xlabel('Total Revenue')
plt.ylabel('Amount ($)')
plt.xticks(df.index, ['Total Revenue'])
plt.tight_layout()
plt.show()

# %%
# Create a cursor object
cr = con.cursor()

# Query data to get product details with original and selling prices
cr.execute('''
    SELECT product_id, product_name, original_price, selling_price
    FROM product
''')
product_data = pd.DataFrame(cr.fetchall(), columns=['product_id', 'product_name', 'original_price', 'selling_price'])

# Calculate profit for each product
product_data['profit'] = product_data['selling_price'] - product_data['original_price']

# Sort products by profit in descending order
product_data = product_data.sort_values(by='profit', ascending=False)

# Plotting the bar chart
plt.figure(figsize=(12, 8))
plt.bar(product_data['product_name'], product_data['profit'], color='royalblue')
plt.title('Most Profitable Products Based on Price Difference')
plt.xlabel('Product Name')
plt.ylabel('Profit ($)')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()

# Display the chart
plt.show()

# Display the profit data
print(product_data[['product_name','profit']])
# Out:
#           product_name  profit
# 0       Wireless Mouse   -4.01
# 14        Formal Shirt   -5.01
# 12             T-shirt   -5.01
# 1   Bluetooth Keyboard   -5.01
# 15             Blender  -10.01
# 13               Jeans  -10.01
# 7     Portable Speaker  -10.01
# 5       Gaming Headset  -10.01
# 16      Microwave Oven  -20.01
# 17      Vacuum Cleaner  -20.01
# 4               Tablet  -20.01
# 9          Smart Watch  -20.01
# 10       Running Shoes  -20.01
# 11      Leather Jacket  -30.01
# 8       Digital Camera  -50.01
# 2           Smartphone  -50.01
# 6           4K Monitor  -50.01
# 3               Laptop -100.01
# 18        Refrigerator -100.01
# 19     Washing Machine -100.01

# %%
# Create a cursor object
cr = con.cursor()

# Query data to get total quantity ordered per product
cr.execute('''
    SELECT p.product_name, SUM(od.quantity) AS total_quantity
    FROM order_details od
    JOIN product p ON od.product_id = p.product_id
    GROUP BY p.product_name
    ORDER BY total_quantity DESC
''')
quantity_data = pd.DataFrame(cr.fetchall(), columns=['product_name', 'total_quantity'])



# Identify products with highest and lowest order quantities
highest_quantity_product = quantity_data.iloc[0]
lowest_quantity_product = quantity_data.iloc[-1]

# Prepare data for the bar chart
chart_data = pd.DataFrame({
    'product_name': [highest_quantity_product['product_name'], lowest_quantity_product['product_name']],
    'total_quantity': [highest_quantity_product['total_quantity'], lowest_quantity_product['total_quantity']]
})

# Plotting the bar chart
plt.figure(figsize=(10, 6))
plt.bar(chart_data['product_name'], chart_data['total_quantity'], color=['green', 'red'])
plt.title('Product Names with Highest and Lowest Order Quantities')
plt.xlabel('Product Name')
plt.ylabel('Total Quantity Ordered')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()

# Display the chart
plt.show()

# Display the quantities data
print(chart_data)
# Out:
#       product_name  total_quantity
# 0          T-shirt            60.0
# 1  Washing Machine            12.0

# %%
# Create a cursor object
cr = con.cursor()

# Query data to get counts of orders by payment mode
cr.execute('''
    SELECT payment_mode, COUNT(*) AS order_count
    FROM order_details
    GROUP BY payment_mode
    ORDER BY order_count DESC
''')
payment_mode_data = pd.DataFrame(cr.fetchall(), columns=['payment_mode', 'order_count'])


# Plotting the bar chart
plt.figure(figsize=(10, 6))
plt.bar(payment_mode_data['payment_mode'], payment_mode_data['order_count'], color='skyblue')
plt.title('Most Preferred Payment Modes')
plt.xlabel('Payment Mode')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()

# Display the chart
plt.show()

# Display the payment mode data
print(payment_mode_data)
# Out:
#   payment_mode  order_count
# 0  Credit Card          120
# 1       PayPal           60
# 2   Debit Card           60

# %%
# Create a cursor object
cr = con.cursor()

# Query data to get total sales by month and year
cr.execute('''
    SELECT DATE_FORMAT(order_date, '%Y-%m') AS month_year, SUM(total_price) AS total_sales
    FROM order_details
    GROUP BY month_year
    ORDER BY month_year
''')
sales_data = pd.DataFrame(cr.fetchall(), columns=['month_year', 'total_sales'])

# Plotting the bar chart
plt.figure(figsize=(12, 8))
plt.bar(sales_data['month_year'], sales_data['total_sales'], color='lightblue')
plt.title('Total Sales Month and Year Wise')
plt.xlabel('Month-Year')
plt.ylabel('Total Sales ($)')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()

# Display the chart
plt.show()

# Display the sales data
print(sales_data)
# Out:
#   month_year  total_sales
# 0    2024-08     81079.08

# %%
# Analyze the distribution of customers across cities
city_distribution = customer_data['city'].value_counts().reset_index()
city_distribution.columns = ['city', 'customer_count']

# Display the DataFrame
print(city_distribution)
# Out:
#            city  customer_count
# 0       Houston               4
# 1   Los Angeles               3
# 2  Indianapolis               3
# 3      New York               2
# 4    Washington               2
# 5      Columbus               2
# 6  Philadelphia               1
# 7       Phoenix               1
# 8       Chicago               1
# 9   San Antonio               1

# %%
# Create a bar plot for city distribution
plt.figure(figsize=(12, 8))
sns.barplot(x='customer_count', y='city', data=city_distribution, palette='viridis',hue='city')

# Add labels and title
plt.xlabel('Number of Customers')
plt.ylabel('City')
plt.title('Distribution of Customers Across Different Cities')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Merge order_data with product_data to get product details
order_product_data = order_data.merge(product_data, on='product_id')

# Merge with customer_data to get city details
order_product_city_data = order_product_data.merge(customer_data, on='customer_id')

# Aggregate total quantity of each product in each city
product_city_quantity = order_product_city_data.groupby(['city', 'product_name']).agg({'quantity': 'sum'}).reset_index()

# Aggregate total quantity of each category in each city
category_city_quantity = order_product_city_data.groupby(['city', 'category']).agg({'quantity': 'sum'}).reset_index()

# Pivot the data for the heatmap
category_heatmap_data = category_city_quantity.pivot(index='city', columns='category', values='quantity').fillna(0)

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(category_heatmap_data, cmap='viridis', annot=True, fmt='g')
plt.title('Category Popularity Heatmap by City')
plt.xlabel('Category')
plt.ylabel('City')
plt.tight_layout()
plt.show()

# %%
# Ensure that 'product_id' columns are in the correct format for merging
order_data['product_id'] = order_data['product_id'].astype(str)
product_data['product_id'] = product_data['product_id'].astype(str)

# Merge order_data with product_data to get product details
order_product_data = order_data.merge(product_data, on='product_id')

# Rename product_name column for clarity after merge
order_product_data.rename(columns={'product_name': 'product_name_x'}, inplace=True)

# Aggregate total quantity of each product
product_sales = order_product_data.groupby('product_name_x').agg({'quantity': 'sum'}).reset_index()

# Sort the products by total quantity in descending order
best_selling_products = product_sales.sort_values(by='quantity', ascending=False)

# Select the top 10 best-selling products
top_10_products = best_selling_products.head(10)

# Print the top 10 best-selling products
print("Top 10 Best-Selling Products:")
print(top_10_products)

# Optional: Plotting the results
plt.figure(figsize=(10, 6))
sns.barplot(x='quantity', y='product_name_x', data=top_10_products, palette='pastel',hue = 'quantity')
plt.xlabel('Total Quantity Sold')
plt.ylabel('Product Name')
plt.title('Top 10 Best-Selling Products')
plt.tight_layout()
plt.show()
# Out:
# Top 10 Best-Selling Products:
#         product_name_x  quantity
# 15             T-shirt      60.0
# 4         Formal Shirt      48.0
# 5       Gaming Headset      48.0
# 2   Bluetooth Keyboard      36.0
# 12       Running Shoes      36.0
# 10    Portable Speaker      36.0
# 0           4K Monitor      24.0
# 13         Smart Watch      24.0
# 19      Wireless Mouse      24.0
# 6                Jeans      24.0

# %%
# Ensure that 'product_id' columns are in the correct format for merging
order_data['product_id'] = order_data['product_id'].astype(str)
product_data['product_id'] = product_data['product_id'].astype(str)

# Merge order_data with product_data to get product details
order_product_data = order_data.merge(product_data, on='product_id')

# Aggregate total quantity of each product
product_sales = order_product_data.groupby('product_name').agg({'quantity': 'sum'}).reset_index()

# Sort the products by total quantity in ascending order to find slow-moving products
slow_moving_products = product_sales.sort_values(by='quantity').head(10)

# Print the top 10 slow-moving products
print("Top 10 Slow-Moving Products:")
print(slow_moving_products)

# Optional: Plotting the top 10 slow-moving products
plt.figure(figsize=(10, 6))
sns.barplot(x='product_name', y='quantity', data=slow_moving_products, palette='viridis',hue = 'quantity')
plt.xlabel('Total Quantity Sold')
plt.ylabel('Product Name')
plt.title('Top 10 Slow-Moving Products')
plt.xticks(rotation =90)
plt.tight_layout()
plt.show()
# Out:
# Top 10 Slow-Moving Products:
#        product_name  quantity
# 1           Blender      12.0
# 3    Digital Camera      12.0
# 7            Laptop      12.0
# 8    Leather Jacket      12.0
# 14       Smartphone      12.0
# 11     Refrigerator      12.0
# 9    Microwave Oven      12.0
# 16           Tablet      12.0
# 18  Washing Machine      12.0
# 6             Jeans      24.0
